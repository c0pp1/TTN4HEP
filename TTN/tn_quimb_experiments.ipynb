# %% [markdown]
# # Experiments with QUIMB
# ## Imports

# %%
import quimb as qu
from quimb import tensor as qtn
from utils import *
from ttn_quimb import TTN, TNModel, check_correct_init
# Out:
# /media/alberto/Volume/Kubuntu/PoD/Thesis/TN4HEP/TTN/utils.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# %config InlineBackend.figure_formats = ['svg']

# %%
import torch
from torchinfo import summary
import torchvision as tv
import numpy as np
import pandas as pd
import string
from tqdm.notebook import tqdm, trange
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Try a TTN on MNIST

# %% [markdown]
# ## Preprocess

# %%
h = 8
BATCH_SIZE = 64

train_dl, test_dl, train_visual = get_mnist_data_loaders(h, batch_size=BATCH_SIZE)

# %%
images, labels = next(iter(train_visual))
images = images[:16,0]

fig, axs = plt.subplots(4, 4, figsize=(10,10))

for i, ax in enumerate(axs.flatten()):
    ax.imshow(images[i], cmap='gray')
    ax.set_title(f'{labels[i]}')
    ax.set_axis_off()

# %% [markdown]
# ## Define model

# %%
def loss(labels, output):
    return torch.mean(torch.sum((output - torch.nn.functional.one_hot(labels))**2, 1))/2

# %%
n_labels = 2
BOND_DIM = 8
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
INIT = True

MyTTN = TTN(h**2, n_labels=n_labels, bond_dim=BOND_DIM, device=DEVICE)
model = TNModel(MyTTN, init={'initialize': INIT, 'dataloader': train_dl, 'loss_fn': loss}, batched_forward=False)
model.draw()
summary(model, input_size=next(iter(train_dl))[0].squeeze().shape, dtypes=[torch.complex128])
# Out:
# preparing dataset:   0%|          | 0/186 [00:00<?, ?it/s]
# ttn unsupervised init:   0%|          | 0/992 [00:00<?, ?it/s]
# ttn supervised init:   0%|          | 0/186 [00:00<?, ?it/s]
#   0%|          | 0/186 [00:00<?, ?it/s]
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TNModel                                  [64, 2]                   9,856
# ==========================================================================================
# Total params: 9,856
# Trainable params: 9,856
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0
# ==========================================================================================
# Input size (MB): 0.13
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.13
# ==========================================================================================

# %%
check_correct_init(model)
# Out:
# (True, 0)

# %% [markdown]
# ## Training with pytorch

# %%
def train_one_epoch(model, device, train_dl, loss_fn, optimizer):
    running_loss = 0.
    last_loss = 0.
    last_batch = 0
    loss_history = []

    pbar = tqdm(enumerate(train_dl), total=len(train_dl),position=0)
    for i, data in enumerate(train_dl):

        # Every data instance is an input + label pair
        inputs, labels = data
        inputs, labels = inputs.squeeze().to(device, dtype=torch.complex128, non_blocking=True), labels.to(device)

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs)
        probs = torch.real(torch.pow(outputs, 2))

        probs = probs / torch.sum(probs)

        # Compute the loss and its gradients
        loss = loss_fn(labels, probs)
        loss.backward()
        
        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()
        loss_history.append(loss.item())
        if i % 10 == 9:
            last_batch = i+1
            last_loss = running_loss / 10 # mean loss over 10 batches
            running_loss = 0.  
        pbar.update()
        pbar.set_postfix({'current loss': loss.item(), f'batches {last_batch-10}-{last_batch} loss': last_loss})
        
    pbar.set_postfix({'current loss': loss.item(), f'batches {last_batch-10}-{last_batch} loss': last_loss, 'epoch mean loss': np.array(loss_history).mean()}) # not correct as the last batch is averaged on less samples
    pbar.close()
    return loss_history

# %%
LR = 1e-1
EPOCHS = 10
SCHEDULER_STEPS = 8

model.train()
model.to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ConstantLR(optimizer, .5, SCHEDULER_STEPS)

# %%
tot_loss_history = []
now = datetime.now()
for epoch in trange(EPOCHS):
    loss_history = train_one_epoch(model, DEVICE, train_dl, loss, optimizer)
    tot_loss_history += loss_history
    scheduler.step()
    
loss_history = np.array(tot_loss_history)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/186 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb Cell 16 line 4
#       <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> now = datetime.now()
#       <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> for epoch in trange(EPOCHS):
# ----> <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     loss_history = train_one_epoch(model, DEVICE, train_dl, loss, optimizer)
#       <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     tot_loss_history += loss_history
#       <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>     scheduler.step()
#
# /home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a> # Compute the loss and its gradients
#      <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=23'>24</a> loss = loss_fn(labels, probs)
# ---> <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=24'>25</a> loss.backward()
#      <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=26'>27</a> # Adjust learning weights
#      <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experiments.ipynb#X21sZmlsZQ%3D%3D?line=27'>28</a> optimizer.step()
#
# File ~/Desktop/Thesis/TN4HEP/.ttn_venv/lib/python3.11/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/Desktop/Thesis/TN4HEP/.ttn_venv/lib/python3.11/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict, f'models/trainedmodel_{now.strftime("%Y%m%d-%H%M%S")}.dict')
np.save(f'models/loss_history_{now.strftime("%Y%m%d-%H%M%S")}.npy', loss_history)

# %%
plt.plot(range(len(loss_history)), loss_history)
plt.ylim(0, 2)
print(np.mean(loss_history[-10:]))
# Out:
# 0.4959501515442891

# %%
plt.plot([loss_history[i*len(train_dl):((i+1)*len(train_dl) if i<EPOCHS-1 else -1)].mean() for i in range(EPOCHS)])
plt.ylim(0, 1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.show()

# %%
accuracy(model, DEVICE, train_dl, test_dl)
# Out:
# test:   0%|          | 0/31 [00:00<?, ?it/s]
# train:   0%|          | 0/186 [00:00<?, ?it/s]
# (0.4989869998311666, 0.4872448979591837)

# %% [markdown]
# # Deprecated code

# %% [markdown]
# ## Training with quimb
#
# not possible as the quimb optimization suppose the measurement of an hamiltonian and the minimization of the energy, not suitable if data are supplied during the training process. We would have to think about an hamiltonian whose ground state is the state we want.

# %%
tnopt = qtn.TNOptimizer(
    # the tensor network we want to optimize
    MyTTN.net,
    # the functions specfying the loss and normalization
    loss_fn=loss_fn,
    #norm_fn=norm_fn,
    # we specify constants so that the arguments can be converted
    # to the  desired autodiff backend automatically
    #loss_constants={"ham": ham},
    # the underlying algorithm to use for the optimization
    # 'l-bfgs-b' is the default and often good for fast initial progress
    optimizer="adam",
    autodiff_backend="torch",
)
tnopt
# Out:
# <TNOptimizer(d=34048, backend=torch)>

# %%
tnopt.optimize(100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experimenrts.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/home/alberto/Desktop/Thesis/TN4HEP/TTN/tn_quimb_experimenrts.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> tnopt.optimize(100)
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/quimb/tensor/optimize.py:1409, in TNOptimizer.optimize(self, n, tol, jac, hessp, optlib, **options)
#    1376 def optimize(
#    1377     self, n, tol=None, jac=True, hessp=False, optlib="scipy", **options
#    1378 ):
#    1379     """Run the optimizer for ``n`` function evaluations, using by default
#    1380     :func:`scipy.optimize.minimize` as the driver for the vectorized
#    1381     computation. Supplying the gradient and hessian vector product is
#    (...)
#    1407     tn_opt : TensorNetwork
#    1408     """
# -> 1409     return {"scipy": self.optimize_scipy, "nlopt": self.optimize_nlopt,}[
#    1410         optlib
#    1411     ](n=n, tol=tol, jac=jac, hessp=hessp, **options)
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/quimb/tensor/optimize.py:1429, in TNOptimizer.optimize_scipy(self, n, tol, jac, hessp, **options)
#    1427 try:
#    1428     self._maybe_init_pbar(n)
# -> 1429     self.res = minimize(
#    1430         fun=fun,
#    1431         jac=jac,
#    1432         hessp=self.vectorized_hessp if hessp else None,
#    1433         x0=self.vectorizer.vector,
#    1434         tol=tol,
#    1435         bounds=self.bounds,
#    1436         method=self._method,
#    1437         options=dict(maxiter=n, **options),
#    1438     )
#    1439     self.vectorizer.vector[:] = self.res.x
#    1440 except KeyboardInterrupt:
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/scipy/optimize/_minimize.py:633, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     627         options.setdefault('barrier_tol', tol)
#     629 if meth == '_custom':
#     630     # custom method called before bounds and constraints are 'standardised'
#     631     # custom method should be able to accept whatever bounds/constraints
#     632     # are provided to it.
# --> 633     return method(fun, x0, args=args, jac=jac, hess=hess, hessp=hessp,
#     634                   bounds=bounds, constraints=constraints,
#     635                   callback=callback, **options)
#     637 constraints = standardize_constraints(constraints, x0, meth)
#     639 remove_vars = False
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/quimb/tensor/optimize.py:845, in ADAM.__call__(self, fun, x0, jac, args, learning_rate, beta1, beta2, eps, maxiter, callback, bounds, **kwargs)
#     842 for _ in range(maxiter):
#     843     self._i += 1
# --> 845     g = jac(x)
#     847     if callback and callback(x):
#     848         break
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/scipy/optimize/_optimize.py:81, in MemoizeJac.derivative(self, x, *args)
#      80 def derivative(self, x, *args):
# ---> 81     self._compute_if_needed(x, *args)
#      82     return self.jac
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/scipy/optimize/_optimize.py:71, in MemoizeJac._compute_if_needed(self, x, *args)
#      69 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      70     self.x = np.asarray(x).copy()
# ---> 71     fg = self.fun(x, *args)
#      72     self.jac = fg[1]
#      73     self._value = fg[0]
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/quimb/tensor/optimize.py:1289, in TNOptimizer.vectorized_value_and_grad(self, x)
#    1287 self.vectorizer.vector[:] = x
#    1288 arrays = self.vectorizer.unpack()
# -> 1289 result, grads = self.handler.value_and_grad(arrays)
#    1290 self._n += 1
#    1291 self.loss = result.item()
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/quimb/tensor/optimize.py:578, in TorchHandler.value_and_grad(self, arrays)
#     575     self._setup_backend_fn(arrays)
#     577 variables = tree_map(self.to_variable, arrays)
# --> 578 result = self._backend_fn(variables)
#     580 def get_gradient_from_torch(t):
#     581     if t.grad is None:
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/quimb/tensor/optimize.py:1053, in MakeArrayFn.__call__(self, arrays)
#    1051 # set backend explicitly as maybe mixing with numpy arrays
#    1052 with contract_backend(self.autodiff_backend):
# -> 1053     return self.loss_fn(self.norm_fn(tn_compute))
#
# File /media/alberto/Volume/Kubuntu/miniconda3/envs/tn4hep/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: CrossEntropyLoss.forward() missing 1 required positional argument: 'target'

# %% [markdown]
# ## Try TTN on Titanic dataset

# %%
from torch.utils.data import Dataset, DataLoader

dataset = pd.read_csv('../data/titanic.csv')
data_trimmed = dataset.drop(['Name', 'Ticket'], axis=1).copy()

# %%
def convert_single_cab(cab):
    result = 0
    num_pow = 0
    alpha_pow = 3
    if pd.isna(cab): return 0
    else:
        for char in cab[::-1]:
            if char.isdigit():
                result += 10**num_pow*int(char)
                num_pow += 1
            elif char.isalpha():
                result += 10**alpha_pow*(string.ascii_uppercase.index(char)+1)
            elif char.isspace():
                continue
            else:
                print('Error converting cabin number')
                return None
        return result
    
def convert_cabs(cabs):
    if pd.isna(cabs): return 0
    else: return np.mean(list(map(convert_single_cab, cabs.split())))

miao = data_trimmed['Cabin'].apply(convert_cabs)

# %%
class TitanicDataset(Dataset):
    def __init__(self, filepath, transform=None):
        self.data = pd.read_csv(filepath)
    
        # convert to numerical
        self.data['Cabin_num'] = self.data['Cabin'].apply(convert_cabs)
        self.data['Sex_num'] = pd.Categorical(self.data['Sex']).codes
        self.data['Embarked_num'] = pd.Categorical(self.data['Embarked']).codes

        #trim useless columns
        self.data = self.data.drop(['PassengerId', 'Name', 'Sex', 'Cabin', 'Embarked', 'Ticket'], axis=1).dropna(axis=0).copy()

        self.transform = transform
        
    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):
        label = np.array(self.data.iloc[idx, 0])
        data = np.array(self.data.iloc[idx, 1:])

        if self.transform:
            data = self.transform(data)

        return data, label

# %%
titanic_dataset = TitanicDataset('../data/titanic.csv', transform=tv.transforms.Lambda(quantize))

titanic_dl = DataLoader(titanic_dataset, batch_size=64)

# %%
datum = next(iter(titanic_dl))[0]
datum.shape
# Out:
# torch.Size([64, 8, 2])

# %%
titanic_TTN = TTN(8)
titanic_model = TNModel(titanic_TTN)
titanic_model.draw()

# %%
loss_fn = torch.nn.BCELoss()
optimizer = torch.optim.Adam(titanic_model.parameters())

# %%
titanic_model.train()
train_one_epoch(titanic_model, titanic_dl)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# [-98.08844112977505, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %% [markdown]
# ## Code examples from quimb official site

# %%
data = qu.bell_state('psi-').reshape(2, 2)
inds = ('k0', 'k1')
tags = ('KET',)

ket = qtn.Tensor(data=data, inds=inds, tags=tags)
ket
# Out:
# Tensor(shape=(2, 2), inds=('k0', 'k1'), tags=oset(['KET']))

# %%
ket.draw()

# %%
X = qtn.Tensor(qu.pauli('X'), inds=('k0', 'b0'), tags=['PAULI', 'X', '0'])
Y = qtn.Tensor(qu.pauli('Y'), inds=('k1', 'b1'), tags=['PAULI', 'Y', '1'])
bra = qtn.Tensor(qu.rand_ket(4).reshape(2, 2), inds=('b0', 'b1'), tags=['BRA'])
X
# Out:
# Tensor(shape=(2, 2), inds=('k0', 'b0'), tags=oset(['PAULI', 'X', '0']))

# %%
TN = ket.H & X & Y & bra
TN
# Out:
# TensorNetwork(tensors=4, indices=4)

# %%
TN.draw(color=['KET', 'PAULI', 'BRA'], figsize=(4, 4), show_inds='all')

# %%
TN ^ ...
# Out:
# (-0.09308328668288901+0.1331677810864347j)

# %% [markdown]
# ## Let's try to build a TTN

# %%
# generating a random MPS

ket_mps = qtn.MPS_rand_state(4, 1, site_ind_id='a{}')
ket_mps.draw()

# %%
ket_mps.apply_to_arrays(lambda x: torch.tensor(x, dtype=torch.float32, requires_grad=True))
ket_mps
# Out:
# MatrixProductState(tensors=4, indices=7, L=4, max_bond=2)

# %%
T1 = qtn.rand_tensor((2,2,4), inds=('a0', 'a1', 'b0'), tags=['l1'])
T2 = qtn.rand_tensor((2,2,4), inds=('a2', 'a3', 'b1'), tags=['l1'])
T3 = qtn.rand_tensor((4, 4, 2), inds=('b0', 'b1', 'c0'), tags=['l2'])

TN = T1 & T2 & T3
TN.draw(color=['l1', 'l2'], show_inds='all')
TN.apply_to_arrays(lambda x: torch.tensor(x, dtype=torch.float32, requires_grad=True))

# %%
(TN & ket_mps).draw(color=['l1', 'l2'], show_inds='all', fix={'I{}'.format(i): (i, 5) for i in range(4)} )

# %%
contr = (TN & ket_mps).contract(..., backend='torch')

# %%
contr.data
# Out:
# tensor([-10.9518,   1.9017], grad_fn=<ViewBackward0>)

# %%
# outdated (does not take into account the min(2^l, chi) rule)
def th_nparams(ttn):
    # return the expected number of parameters in the TN
    # based on TN structure
    return ttn.n_features*2*ttn.bond_dim+ttn.bond_dim**3*2*(2**(ttn.n_layers-2)-1)+ttn.bond_dim**2*ttn.n_labels

th_nparams(MyTTN)
# Out:
# 16512
