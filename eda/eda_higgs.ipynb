# %% [markdown]
# # Exploratory data analysis for HIGGS

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
datadir = "../data/Higgs/higgs_small.csv"
df = pd.read_csv(datadir)
df.head()
# Out:
#    label  lepton_pT  lepton_eta  lepton_phi  missing_energy_magnitude  \
# 0    1.0   0.869293   -0.635082    0.225690                  0.327470
# 1    1.0   0.907542    0.329147    0.359412                  1.497970
# 2    1.0   0.798835    1.470639   -1.635975                  0.453773
# 3    0.0   1.344385   -0.876626    0.935913                  1.992050
# 4    1.0   1.105009    0.321356    1.522401                  0.882808
#
#    missing_energy_phi   jet1_pt  jet1_eta  jet1_phi  jet1_b-tag  ...  \
# 0           -0.689993  0.754202 -0.248573 -1.092064    0.000000  ...
# 1           -0.313010  1.095531 -0.557525 -1.588230    2.173076  ...
# 2            0.425629  1.104875  1.282322  1.381664    0.000000  ...
# 3            0.882454  1.786066 -1.646778 -0.942383    0.000000  ...
# 4           -1.205349  0.681466 -1.070464 -0.921871    0.000000  ...
#
#    jet4_eta  jet4_phi  jet4_b-tag      m_jj     m_jjj      m_lv     m_jlv  \
# ...

# %%
signal = df[df["label"] == 1]
background = df[df["label"] == 0]

inv_masses = list(df.columns[-7:]) + ["missing_energy_magnitude"]
inv_masses
# Out:
# ['m_jj',
#  'm_jjj',
#  'm_lv',
#  'm_jlv',
#  'm_bb',
#  'm_wbb',
#  'm_wwbb',
#  'missing_energy_magnitude']

# %%
fig, ax = plt.subplots(2, 4, figsize=(15, 7))
ax = ax.flatten()

for i, mass in enumerate(inv_masses):
    ax[i].hist(signal[mass], bins=50, density=True, alpha=0.5, label="signal")
    ax[i].hist(background[mass], bins=50, density=True, alpha=0.5, label="background")
    ax[i].set_title(mass, fontsize=16)
    ax[i].tick_params(axis='both', which='major', labelsize=12)

ax[0].legend()
ax[0].set_ylabel("Density", fontsize=14)
ax[4].set_ylabel("Density", fontsize=14)

fig.tight_layout()
fig.savefig('../images/higgs_masses.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 6
#       4 for i, mass in enumerate(inv_masses):
#       5     ax[i].hist(signal[mass], bins=50, density=True, alpha=0.5, label="signal")
# ----> 6     ax[i].hist(background[mass], bins=50, density=True, alpha=0.5, label="background", fmt='o')
#       7     ax[i].set_title(mass, fontsize=16)
#       8     ax[i].tick_params(axis='both', which='major', labelsize=12)
#
# File ~/data/ttn4hep/.ttn_venv/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %%
sns.pairplot(df, hue="label", vars=inv_masses)
plt.show()
plt.savefig('../images/higgs_pairplot.pdf')
