# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('../data/titanic/titanic.csv')
data
# Out:
#       pclass  survived     sex      age  sibsp  parch  ticket      fare  \
# 0        1.0         1  female  29.0000    0.0    0.0   24160  211.3375
# 1        1.0         1    male   0.9167    1.0    2.0  113781  151.5500
# 2        1.0         0  female   2.0000    1.0    2.0  113781  151.5500
# 3        1.0         0    male  30.0000    1.0    2.0  113781  151.5500
# 4        1.0         0  female  25.0000    1.0    2.0  113781  151.5500
# ...      ...       ...     ...      ...    ...    ...     ...       ...
# 1038     3.0         0    male  45.5000    0.0    0.0    2628    7.2250
# 1039     3.0         0  female  14.5000    1.0    0.0    2665   14.4542
# 1040     3.0         0    male  26.5000    0.0    0.0    2656    7.2250
# 1041     3.0         0    male  27.0000    0.0    0.0    2670    7.2250
# 1042     3.0         0    male  29.0000    0.0    0.0  315082    7.8750
#
#      embarked
# 0           S
# 1           S
# 2           S
# 3           S
# 4           S
# ...

# %%
sns.pairplot(data=data)

# %%
sns.scatterplot(data=data, x='age', y='sibsp', hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='sibsp'>

# %%
sns.scatterplot(data=data, x='parch', y='fare', hue='survived')
# Out:
# <Axes: xlabel='parch', ylabel='fare'>

# %%
sns.scatterplot(data=data, x='fare', y='pclass', hue='survived')
# Out:
# <Axes: xlabel='fare', ylabel='pclass'>

# %%
data[['age', 'sibsp']].corr(), data[['parch', 'fare']].corr(), data[['fare', 'pclass']].corr()
# Out:
# (            age     sibsp
#  age    1.000000 -0.242345
#  sibsp -0.242345  1.000000,
#           parch     fare
#  parch  1.00000  0.21765
#  fare   0.21765  1.00000,
#              fare    pclass
#  fare    1.000000 -0.564558
#  pclass -0.564558  1.000000)
